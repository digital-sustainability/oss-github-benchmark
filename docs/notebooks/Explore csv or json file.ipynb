# %%
import pandas as pd

# %%
df = pd.read_csv('./oss-github-benchmark.csv')
df
# Out:
#    sector                   name  num_repos  num_members  \
# 0      IT           4teamwork AG        259           31
# 1      IT              56K Cloud          7            3
# 2      IT        Adfinis SyGroup        251           21
# 3      IT  AdNovum Informatik AG         34            0
# 4     NaN                Abraxas          0            1
# ..    ...                    ...        ...          ...
# 64    NaN          Kanton Zürich          0            0
# 65    NaN                 Zürich          0            0
# 66    NaN                   Bern          0            0
# 67    NaN  Berner Fachhochschule          0            0
# 68    NaN       Universität Bern          0            0
#
#     total_num_contributors  total_num_own_repo_forks  \
# 0                       86                        12
# 1                       11                        86
# 2                       31                        46
# 3                       16                        53
# ...

# %%
df2 = pd.read_csv('./oss-github-benchmark2.csv')
df2
# Out:
#          sector                   name  num_repos  num_members  \
# 0   Gov_Cantons     Kanton Basel-Stadt         26            0
# 1   Gov_Cantons            Kanton Bern          2            0
# 2   Gov_Cantons       Kanton Neuenburg         28            8
# 3   Gov_Cantons       Kanton Solothurn         70            0
# 4   Gov_Cantons           Kanton Waadt          9            0
# 5   Gov_Cantons          Kanton Zürich         78            7
# 6    Gov_Cities                 Zürich         28            5
# 7    Gov_Cities                   Bern          2            0
# 8  Universities  Berner Fachhochschule         18            3
# 9  Universities       Universität Bern        147           14
#
#    total_num_contributors  total_num_own_repo_forks  total_num_forks_in_repos  \
# 0                      36                        15                         7
# 1                       7                         4                         0
# ...

# %%
df[df.num_repos==0]
# Out:
#    sector                   name  num_repos  num_members  \
# 4     NaN                Abraxas          0            1
# 34    NaN           dat.alets.ch          0            0
# 63    NaN           Kanton Waadt          0            0
# 64    NaN          Kanton Zürich          0            0
# 65    NaN                 Zürich          0            0
# 66    NaN                   Bern          0            0
# 67    NaN  Berner Fachhochschule          0            0
# 68    NaN       Universität Bern          0            0
#
#     total_num_contributors  total_num_own_repo_forks  \
# 4                        0                         0
# 34                       0                         0
# 63                       0                         0
# 64                       0                         0
# 65                       0                         0
# 66                       0                         0
# 67                       0                         0
# ...

# %%
[len(df), len(df[df.num_repos==0]), len(df.dropna())]
# Out:
# [69, 8, 60]

# %%
final_df = pd.concat([df.dropna(), df2])
final_df
# Out:
#           sector                   name  num_repos  num_members  \
# 0             IT           4teamwork AG        259           31
# 1             IT              56K Cloud          7            3
# 2             IT        Adfinis SyGroup        251           21
# 3             IT  AdNovum Informatik AG         34            0
# 5             IT              amazee.io         83            6
# ..           ...                    ...        ...          ...
# 5    Gov_Cantons          Kanton Zürich         78            7
# 6     Gov_Cities                 Zürich         28            5
# 7     Gov_Cities                   Bern          2            0
# 8   Universities  Berner Fachhochschule         18            3
# 9   Universities       Universität Bern        147           14
#
#     total_num_contributors  total_num_own_repo_forks  \
# 0                       86                        12
# 1                       11                        86
# ...

# %%
len(final_df)
# Out:
# 70

# %%
final_df.drop_duplicates(subset='name', keep="last")
# Out:
#           sector                   name  num_repos  num_members  \
# 0             IT           4teamwork AG        259           31
# 1             IT              56K Cloud          7            3
# 2             IT        Adfinis SyGroup        251           21
# 3             IT  AdNovum Informatik AG         34            0
# 5             IT              amazee.io         83            6
# ..           ...                    ...        ...          ...
# 5    Gov_Cantons          Kanton Zürich         78            7
# 6     Gov_Cities                 Zürich         28            5
# 7     Gov_Cities                   Bern          2            0
# 8   Universities  Berner Fachhochschule         18            3
# 9   Universities       Universität Bern        147           14
#
#     total_num_contributors  total_num_own_repo_forks  \
# 0                       86                        12
# 1                       11                        86
# ...

# %%
final_df.to_csv('oss-github-benchmark-merged.csv')
