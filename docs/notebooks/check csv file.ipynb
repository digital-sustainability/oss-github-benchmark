# %%
import pandas as pd

# %%
result = pd.read_csv('./oss-github-benchmark.csv')
result
# Out:
#           sector                   name  num_repos  num_members  \
# 0            NaN           4teamwork AG          0            0
# 1             IT              56K Cloud          7            3
# 2             IT        Adfinis SyGroup        251           21
# 3             IT  AdNovum Informatik AG         34            0
# 4            NaN                Abraxas          0            1
# ..           ...                    ...        ...          ...
# 64   Gov_Cantons          Kanton Zürich         78            7
# 65    Gov_Cities                 Zürich         28            5
# 66    Gov_Cities                   Bern          2            0
# 67  Universities  Berner Fachhochschule         18            3
# 68  Universities       Universität Bern        147           14
#
#     total_num_contributors  total_num_own_repo_forks  \
# 0                        0                         0
# 1                       11                        86
# ...

# %%
result[result['num_repos']==0]
# Out:
#    sector          name  num_repos  num_members  total_num_contributors  \
# 0     NaN  4teamwork AG          0            0                       0
# 4     NaN       Abraxas          0            1                       0
# 34    NaN  dat.alets.ch          0            0                       0
#
#     total_num_own_repo_forks  total_num_forks_in_repos  total_num_stars  \
# 0                          0                         0                0
# 4                          0                         0                0
# 34                         0                         0                0
#
#     total_commits_last_year              orgs  \
# 0                         0                []
# 4                         0  ['abraxas-labs']
# 34                        0                []
#
#                                                avatar repo_names
# 0                                                  []         []
# 4   ['https://avatars0.githubusercontent.com/u/591...         []
# ...
